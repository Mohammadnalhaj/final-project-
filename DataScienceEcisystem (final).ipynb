# %% [markdown]
# # Data science Tools and ecosystem

# %% [markdown]
# In this notebook, **data science tools** and **ecosystem** are summarized

# %% [markdown]
# **Objectives:**
# - listing popular languages for data science
# - list common libraries in data science
# - create a table of open-source development tools
# - convert minutes to hours with simple experssion

# %% [markdown]
# Some of the popular used languages that data scientists use are:
# 1. python
# 2. R
# 3. SQL
# 4. Julia

# %% [markdown]
# some of the commonly used libraries used by data scientists include:
# 1. pandas
# 2. NumPy
# 3. Matplotlib
# 4. scikit-learn

# %% [markdown]
# | Data Science Tools |
# | --- |
# | Jupyterlab |
# | RStudio |
# | VS Code |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Mohammad
